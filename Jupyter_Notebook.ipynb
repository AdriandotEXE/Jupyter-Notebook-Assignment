# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
#  "My Jupyter Notebook on IBM Watson Studio",

# %% [markdown]
# __Adrian Torres__
# Data Scientist I

# %% [markdown]
# _I am interested in data science because it gives me an opportunity to solve puzzles and make lots of money simultaneously._

# %% [markdown]
# ## It is supposed to print my name

# %%
print("Adrian")
# Out:
# Adrian

# %% [markdown]
#  # Abstract Art 101
#  &#25A3
#  ## Reasons Abstract Art is "Good"
#  ***
#  ***
#  ***
#
#  1. _Perception_
#  2. _Anti-Conforming_
#  3. _Reputation of Artist_
#
#
#
#  ***
#  ***
#  ***
#  ### Example
#
#
#
#
#
#  ![WpjAqQqC3qyLzZsvhY9p.jpg](attachment:c4fa7fd1-64e6-4878-9a8d-c277a119b98d.jpg)
